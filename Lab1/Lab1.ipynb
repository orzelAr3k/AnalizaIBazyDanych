# %% [markdown]
# # Analizy i bazy danych - Lab 1
#
# ## Arkadiusz Orzeł 403481

# %% [markdown]
# **Zadanie 3**

# %%
# import
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
# funkcja
f = lambda x: x ** 2 + 5

# %%
x1 = np.arange(-1, 1, 0.1)
plt.plot(x1, f(x1), label="Funkcja $x^2+5$")
plt.title("Wykres fukcji $x^2+5$ na przedziale $-1<x<1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()

# %%
x2 = np.arange(-6, 6, 0.1)
plt.plot(x2, f(x2), label="Funkcja $x^2+5$")
plt.title("Wykres fukcji $x^2+5$ na przedziale $-6<x<6$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()

# %%
x3 = np.arange(0, 5, 0.1)
plt.plot(x3, f(x3), label="Funkcja $x^2+5$")
plt.title("Wykres fukcji $x^2+5$ na przedziale $-0<x<5$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()

# %% [markdown]
# **Zadanie 4**

# %%
# dane
d = {
    'name': ['Bartek', 'Franek', 'Janusz', 'Agnieszka', 'Michał'],
    'surname' :['Kowalski', 'Jakubowski', 'Kalinowski', 'Adamert', 'Banach'],
    'age': [24, 21, 45, 23, 21],
    'sex': ['mężczyzna', 'mężczyzna', 'mężczyzna', 'kobieta', 'mężczyzna']
    }

# Stworzenie obiektu DataFrame
df = pd.DataFrame(data=d)
print(df)
# Out:
#         name     surname  age        sex
# 0     Bartek    Kowalski   24  mężczyzna
# 1     Franek  Jakubowski   21  mężczyzna
# 2     Janusz  Kalinowski   45  mężczyzna
# 3  Agnieszka     Adamert   23    kobieta
# 4     Michał      Banach   21  mężczyzna

# %% [markdown]
# - Wyświetlenie informacji o danych **(pandas info)**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %% [markdown]
# - Wyświetlenie opisu danych **(pandas describe)**

# %%
df.describe()
# Out:
#              age
# count   5.000000
# mean   26.800000
# std    10.256705
# min    21.000000
# 25%    21.000000
# 50%    23.000000
# 75%    24.000000
# max    45.000000

# %% [markdown]
# - Wyświetlenie pierwszych trzech rekordów **(pandas head)**

# %%
df.head(3)
# Out:
#      name     surname  age        sex
# 0  Bartek    Kowalski   24  mężczyzna
# 1  Franek  Jakubowski   21  mężczyzna
# 2  Janusz  Kalinowski   45  mężczyzna
